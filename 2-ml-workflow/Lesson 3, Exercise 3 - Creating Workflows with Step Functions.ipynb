# %% [markdown]
# # UDACITY Designing Your First Workflow - Step Functions

# %% [markdown]
# ## Step Functions & SageMaker

# %% [markdown]
# In the prior exercises, we've been working with many small services. This can be overwhelming for a data scientist that wants to establish a consistent methodology for handling data. Step Functions is an orchestration service that can allow us to utilize SageMaker in a methodical and consistent way. Step Functions also integrates with Lambda, which can allow us to potentially automate our entire machine learning pipeline end-to-end. Let's get a handle on what a 'step' in a step function looks like.
#
# In this exercise, you will create a preprocessing step and a training step. Then you will create a step function to chain the two steps.

# %% [markdown]
# ## Exercise: Grant Permissions and install packages.

# %% [markdown]
# Attach the IAMFullAccess and the StepFunctionsFullAccess polices to your SageMaker execution role.

# %%
# %pip install stepfunctions
# Out:
# Requirement already satisfied: stepfunctions in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: sagemaker>=2.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from stepfunctions) (2.182.0)
# Requirement already satisfied: boto3>=1.14.38 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from stepfunctions) (1.28.40)
# Requirement already satisfied: pyyaml in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from stepfunctions) (6.0)
# Requirement already satisfied: botocore<1.32.0,>=1.31.40 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3>=1.14.38->stepfunctions) (1.31.40)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3>=1.14.38->stepfunctions) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3>=1.14.38->stepfunctions) (0.6.1)
# Requirement already satisfied: attrs<24,>=23.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (23.1.0)
# Requirement already satisfied: cloudpickle==2.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (2.2.1)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (1.22.3)
# Requirement already satisfied: protobuf<5.0,>=3.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (4.24.2)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (1.0.1)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (6.8.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (21.3)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (2.0.3)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (0.3.1)
# Requirement already satisfied: schema in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (0.7.5)
# Requirement already satisfied: jsonschema in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (4.18.4)
# Requirement already satisfied: platformdirs in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (3.9.1)
# Requirement already satisfied: tblib==1.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (1.7.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.32.0,>=1.31.40->boto3>=1.14.38->stepfunctions) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.32.0,>=1.31.40->boto3>=1.14.38->stepfunctions) (1.26.14)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker>=2.1.0->stepfunctions) (3.16.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging>=20.0->sagemaker>=2.1.0->stepfunctions) (3.0.9)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from google-pasta->sagemaker>=2.1.0->stepfunctions) (1.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->sagemaker>=2.1.0->stepfunctions) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->sagemaker>=2.1.0->stepfunctions) (0.30.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->sagemaker>=2.1.0->stepfunctions) (0.9.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas->sagemaker>=2.1.0->stepfunctions) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas->sagemaker>=2.1.0->stepfunctions) (2023.3)
# Requirement already satisfied: ppft>=1.7.6.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker>=2.1.0->stepfunctions) (1.7.6.7)
# Requirement already satisfied: dill>=0.3.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker>=2.1.0->stepfunctions) (0.3.7)
# Requirement already satisfied: pox>=0.3.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker>=2.1.0->stepfunctions) (0.3.3)
# Requirement already satisfied: multiprocess>=0.70.15 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker>=2.1.0->stepfunctions) (0.70.15)
# Requirement already satisfied: contextlib2>=0.5.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from schema->sagemaker>=2.1.0->stepfunctions) (21.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Exercise: Fill out preprocessing step.

# %% [markdown]
# The 'step' interface is designed to be quite similar to the Preprocessing Job in lesson 2. The main difference between these is the ability of a 'step' to interface with other steps. Given the successful outcome of a single step, the next step specified in a workflow will automatically continue. In our case, a training step will launch given the successful outcome of a preprocessing step. The preprocessing step has been encoded for you. Upload the preprocessing code 'HelloBlazePreprocess.py' and the zipped dataset 'reviews_Musical_Instruments_5.json.zip' to s3, and fill out the constants in the code below.

# %% [markdown]
# Code below is the preprocessing step. Fill in the constants in the code.

# %%
from datetime import datetime
from sagemaker import get_execution_role
from sagemaker.sklearn.processing import SKLearnProcessor
from sagemaker.processing import ProcessingInput, ProcessingOutput
from stepfunctions.steps.sagemaker import ProcessingStep
import sagemaker

role = get_execution_role()

VERSION = datetime.now().strftime("%Y-%m-%d-%H%M%S")
PREPROCESSING_JOB_NAME = "hello-blaze-preprocess-" + VERSION
input_data = 's3://udacity-ml-workflow/Lesson 3, Exercise 3/reviews_Musical_Instruments_5.json.zip'
input_preprocessing_code = 's3://udacity-ml-workflow/Lesson 3, Exercise 3/HelloBlazePreprocess.py'
sess = sagemaker.Session()

sklearn_processor = SKLearnProcessor(framework_version='0.20.0',
                                     role=role,
                                     instance_type='ml.m5.large',
                                     instance_count=1)


processed_data_train = "s3://udacity-ml-workflow/Lesson 3, Exercise 3/hello_blaze_train_scikit"
processed_data_test = "s3://udacity-ml-workflow/Lesson 3, Exercise 3/hello_blaze_test_scikit"

inputs=[ProcessingInput(source=input_data, destination='/opt/ml/processing/input', input_name ='input'),  
        ProcessingInput(source=input_preprocessing_code, destination='/opt/ml/processing/input/code', input_name ='code')]


outputs=[ProcessingOutput(source='/opt/ml/processing/output/train', destination=processed_data_train, output_name='train_data'), 
         ProcessingOutput(source='/opt/ml/processing/output/test', destination=processed_data_test, output_name='test_data')]


processing_step = ProcessingStep(
    "SageMaker pre-processing",
    processor=sklearn_processor,
    job_name=PREPROCESSING_JOB_NAME,
    inputs=inputs,
    outputs=outputs,
    container_entrypoint=["python3", "/opt/ml/processing/input/code/HelloBlazePreprocess.py"],
)

# %% [markdown]
# ## Exercise: Fill out Training Step

# %% [markdown]
# Upon the success of the preprocessing step, we wish to execute a training step. A training step is defined below. Fill the constants in the code.

# %%
from stepfunctions.steps.sagemaker import TrainingStep
import boto3

WORKFLOW_OUTPUT = "s3://udacity-ml-workflow/Lesson 3, Exercise 3"
TRAINING_JOB_NAME = "hello-blaze-training-" + VERSION

region_name = boto3.Session().region_name
container = sagemaker.image_uris.retrieve(region=region_name, framework="blazingtext", version="latest")

helloBlazeEstimator = sagemaker.estimator.Estimator(
    container,
    role=role,
    instance_count=1,
    instance_type='ml.m5.large',
    volume_size=30,
    max_run=360000,
    input_mode="File",
    output_path=WORKFLOW_OUTPUT,
    sagemaker_session=sess,
)

helloBlazeEstimator.set_hyperparameters(mode='supervised')

training_step = TrainingStep(
    "SageMaker Training",
    estimator=helloBlazeEstimator,
    data={"train": sagemaker.TrainingInput(processed_data_train, content_type="text/plain"), 
          "validation": sagemaker.TrainingInput(processed_data_test, content_type="text/plain")},
    job_name=TRAINING_JOB_NAME,
    wait_for_completion=True,
)

# %% [markdown]
# ## Exercise: Create Workflow & Execute It.

# %% [markdown]
# To link the steps, you'll need to create a role that is capable of doing so. Go to IAM and create a Step Functions role, and attach the CloudWatchEventsFullAccess and SageMakerFullAccess policies. Once done, make use of the above steps to create a workflow. Quick debugging tip: jobs must have a unique name; you'll need to rename job names when debugging. Consider creating a method that will dynamically create unique job names!

# %%
from stepfunctions.steps import Chain
from stepfunctions.workflow import Workflow

workflow_role = 'arn:aws:iam::988060366449:role/StepFunctionRole'

workflow_graph = Chain([processing_step, training_step])
workflow = Workflow(
    name="hello-blaze-workflow",
    definition=workflow_graph,
    role=workflow_role,
)

workflow.create()

execution = workflow.execute(
    inputs={
        "PreprocessingJobName": PREPROCESSING_JOB_NAME,  # Each pre processing job (SageMaker processing job) requires a unique name,
        "TrainingJobName": TRAINING_JOB_NAME  # Each Sagemaker Training job requires a unique name,       
    }
)

execution.get_output(wait=True)
# Out:
# {'SdkResponseMetadata': None,
#  'SdkHttpMetadata': None,
#  'TrainingJobName': 'hello-blaze-training-2023-09-08-213103',
#  'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:988060366449:training-job/hello-blaze-training-2023-09-08-213103',
#  'ProcessingJobArn': None,
#  'TuningJobArn': None,
#  'LabelingJobArn': None,
#  'AutoMLJobArn': None,
#  'ModelArtifacts': {'S3ModelArtifacts': 's3://udacity-ml-workflow/Lesson 3, Exercise 3/hello-blaze-training-2023-09-08-213103/output/model.tar.gz'},
#  'TrainingJobOutput': None,
#  'TrainingJobStatus': 'Completed',
#  'SecondaryStatus': 'Completed',
#  'FailureReason': None,
#  'HyperParameters': {'mode': 'supervised'},
#  'AlgorithmSpecification': {'TrainingImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/blazingtext:1',
#   'TrainingImageConfig': None,
#   'AlgorithmName': None,
#   'TrainingInputMode': 'FILE',
#   'MetricDefinitions': None,
#   'EnableSageMakerMetricsTimeSeries': None,
#   'ContainerEntrypoint': None,
#   'ContainerArguments': None},
#  'RoleArn': 'arn:aws:iam::988060366449:role/service-role/AmazonSageMaker-ExecutionRole-20230817T134927',
#  'InputDataConfig': [{'ChannelName': 'train',
#    'DataSource': {'S3DataSource': {'S3DataType': 'S3_PREFIX',
#      'S3Uri': 's3://udacity-ml-workflow/Lesson 3, Exercise 3/hello_blaze_train_scikit',
#      'S3DataDistributionType': 'FULLY_REPLICATED',
#      'AttributeNames': None,
#      'InstanceGroupNames': None},
#     'FileSystemDataSource': None},
#    'ContentType': 'text/plain',
#    'CompressionType': 'NONE',
#    'RecordWrapperType': 'NONE',
#    'InputMode': None,
#    'ShuffleConfig': None,
#    'EnableFFM': None},
#   {'ChannelName': 'validation',
#    'DataSource': {'S3DataSource': {'S3DataType': 'S3_PREFIX',
#      'S3Uri': 's3://udacity-ml-workflow/Lesson 3, Exercise 3/hello_blaze_train_scikit',
#      'S3DataDistributionType': 'FULLY_REPLICATED',
#      'AttributeNames': None,
#      'InstanceGroupNames': None},
#     'FileSystemDataSource': None},
#    'ContentType': 'text/plain',
#    'CompressionType': 'NONE',
#    'RecordWrapperType': 'NONE',
#    'InputMode': None,
#    'ShuffleConfig': None,
#    'EnableFFM': None}],
#  'OutputDataConfig': {'KmsKeyId': None,
#   'S3OutputPath': 's3://udacity-ml-workflow/Lesson 3, Exercise 3',
#   'CompressionType': None,
#   'RemoveJobNameFromS3OutputPath': None,
#   'DisableModelUpload': None,
#   'Channels': None},
#  'ResourceConfig': {'InstanceType': 'ml.m5.large',
#   'InstanceCount': 1,
#   'VolumeSizeInGB': 30,
#   'VolumeKmsKeyId': None,
#   'KeepAlivePeriodInSeconds': 0,
#   'CapacityReservationIds': None,
#   'InstanceGroups': None},
#  'WarmPoolStatus': None,
#  'VpcConfig': None,
#  'StoppingCondition': {'MaxRuntimeInSeconds': 360000,
#   'MaxWaitTimeInSeconds': None},
#  'CreationTime': 1694208924151,
#  'TrainingStartTime': 1694208993709,
#  'TrainingEndTime': 1694209135685,
#  'LastModifiedTime': 1694209136337,
#  'SecondaryStatusTransitions': [{'Status': 'Starting',
#    'StartTime': 1694208924151,
#    'EndTime': 1694208993709,
#    'StatusMessage': 'Preparing the instances for training'},
#   {'Status': 'Downloading',
#    'StartTime': 1694208993709,
#    'EndTime': 1694209039208,
#    'StatusMessage': 'Downloading input data'},
#   {'Status': 'Training',
#    'StartTime': 1694209039208,
#    'EndTime': 1694209070254,
#    'StatusMessage': 'Training image download completed. Training in progress.'},
#   {'Status': 'Uploading',
#    'StartTime': 1694209070254,
#    'EndTime': 1694209135685,
#    'StatusMessage': 'Uploading generated training model'},
#   {'Status': 'Completed',
#    'StartTime': 1694209135685,
#    'EndTime': 1694209135685,
#    'StatusMessage': 'Training job completed'}],
#  'FinalMetricDataList': None,
#  'EnableNetworkIsolation': None,
#  'EnableInterContainerTrafficEncryption': None,
#  'EnableManagedSpotTraining': None,
#  'CheckpointConfig': None,
#  'TrainingTimeInSeconds': None,
#  'BillableTimeInSeconds': None,
#  'DebugHookConfig': {'LocalPath': None,
#   'S3OutputPath': 's3://udacity-ml-workflow/Lesson 3, Exercise 3',
#   'HookParameters': None,
#   'CollectionConfigurations': None},
#  'ExperimentConfig': None,
#  'DebugRuleConfigurations': None,
#  'TensorBoardOutputConfig': None,
#  'DebugRuleEvaluationStatuses': None,
#  'UpstreamPlatformConfig': None,
#  'ProfilerConfig': None,
#  'ProfilerRuleConfigurations': None,
#  'ProfilerRuleEvaluationStatuses': None,
#  'ProfilingStatus': None,
#  'Environment': None,
#  'RetryStrategy': None,
#  'LastModifiedBy': None,
#  'CreatedBy': None,
#  'DisableEFA': None,
#  'ProcessingJobConfig': None,
#  'RemoteDebugConfig': None,
#  'ResourceTags': None,
#  'Tags': {'AWS_STEP_FUNCTIONS_EXECUTION_ARN': 'arn:aws:states:us-east-1:988060366449:execution:hello-blaze-workflow:38efad29-49c2-4e91-8e2b-cb10acefba5e',
#   'MANAGED_BY_AWS': 'STARTED_BY_STEP_FUNCTIONS'}}

# %% [markdown]
# You can track the outcome of this workflow through a custom UI that gets generated! Check it out!

# %%
execution.render_progress()
# Out:
# <link rel="stylesheet" type="text/css" href="https://do0of8uwbahzz.cloudfront.net/graph.css">
# <div id="graph-694" class="workflowgraph">
#
#     <style>
#         .graph-legend ul {
#             list-style-type: none;
#             padding: 10px;
#             padding-left: 0;
#             margin: 0;
#             position: absolute;
#             top: 0;
#             background: transparent;
#         }
#
#         .graph-legend li {
#             margin-left: 10px;
#             display: inline-block;
#         }
#
#         .graph-legend li > div {
#             width: 10px;
#             height: 10px;
#             display: inline-block;
#         }
#
#         .graph-legend .success { background-color: #2BD62E }
#         .graph-legend .failed { background-color: #DE322F }
#         .graph-legend .cancelled { background-color: #DDDDDD }
#         .graph-legend .in-progress { background-color: #53C9ED }
#         .graph-legend .caught-error { background-color: #FFA500 }
#     </style>
#     <div class="graph-legend">
#         <ul>
#             <li>
#                 <div class="success"></div>
#                 <span>Success</span>
#             </li>
#             <li>
#                 <div class="failed"></div>
#                 <span>Failed</span>
#             </li>
#             <li>
#                 <div class="cancelled"></div>
#                 <span>Cancelled</span>
#             </li>
#             <li>
#                 <div class="in-progress"></div>
#                 <span>In Progress</span>
#             </li>
#             <li>
#                 <div class="caught-error"></div>
#                 <span>Caught Error</span>
#             </li>
#         </ul>
#     </div>
#
#     <svg></svg>
#     <a href="https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:988060366449:execution:hello-blaze-workflow:38efad29-49c2-4e91-8e2b-cb10acefba5e" target="_blank"> Inspect in AWS Step Functions </a>
# </div>
#
# <script type="text/javascript">
#
# require.config({
#     paths: {
#         sfn: "https://do0of8uwbahzz.cloudfront.net/sfn",
#     }
# });
#
# require(['sfn'], function(sfn) {
#     var element = document.getElementById('graph-694')
#
#     var options = {
#         width: parseFloat(getComputedStyle(element, null).width.replace("px", "")),
#         height: 1000,
#         layout: 'LR',
#         resizeHeight: true
#     };
#
#     var definition = {"StartAt": "SageMaker pre-processing step 4", "States": {"SageMaker pre-processing step 4": {"Resource": "arn:aws:states:::sagemaker:createProcessingJob.sync", "Parameters": {"ProcessingJobName": "hello-blaze-preprocess-2023-09-08-213103", "ProcessingInputs": [{"InputName": "input", "AppManaged": false, "S3Input": {"S3Uri": "s3://udacity-ml-workflow/Lesson 3, Exercise 3/reviews_Musical_Instruments_5.json.zip", "LocalPath": "/opt/ml/processing/input", "S3DataType": "S3Prefix", "S3InputMode": "File", "S3DataDistributionType": "FullyReplicated", "S3CompressionType": "None"}}, {"InputName": "code", "AppManaged": false, "S3Input": {"S3Uri": "s3://udacity-ml-workflow/Lesson 3, Exercise 3/HelloBlazePreprocess.py", "LocalPath": "/opt/ml/processing/input/code", "S3DataType": "S3Prefix", "S3InputMode": "File", "S3DataDistributionType": "FullyReplicated", "S3CompressionType": "None"}}], "ProcessingOutputConfig": {"Outputs": [{"OutputName": "train_data", "AppManaged": false, "S3Output": {"S3Uri": "s3://udacity-ml-workflow/Lesson 3, Exercise 3/hello_blaze_train_scikit", "LocalPath": "/opt/ml/processing/output/train", "S3UploadMode": "EndOfJob"}}, {"OutputName": "test_data", "AppManaged": false, "S3Output": {"S3Uri": "s3://udacity-ml-workflow/Lesson 3, Exercise 3/hello_blaze_train_scikit", "LocalPath": "/opt/ml/processing/output/test", "S3UploadMode": "EndOfJob"}}]}, "AppSpecification": {"ImageUri": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-scikit-learn:0.20.0-cpu-py3", "ContainerEntrypoint": ["python3", "/opt/ml/processing/input/code/HelloBlazePreprocess.py"]}, "RoleArn": "arn:aws:iam::988060366449:role/service-role/AmazonSageMaker-ExecutionRole-20230817T134927", "ProcessingResources": {"ClusterConfig": {"InstanceCount": 1, "InstanceType": "ml.m5.large", "VolumeSizeInGB": 30}}}, "Type": "Task", "Next": "SageMaker Training Step"}, "SageMaker Training Step": {"Resource": "arn:aws:states:::sagemaker:createTrainingJob.sync", "Parameters": {"AlgorithmSpecification": {"TrainingImage": "811284229777.dkr.ecr.us-east-1.amazonaws.com/blazingtext:1", "TrainingInputMode": "File"}, "OutputDataConfig": {"S3OutputPath": "s3://udacity-ml-workflow/Lesson 3, Exercise 3"}, "StoppingCondition": {"MaxRuntimeInSeconds": 360000}, "ResourceConfig": {"VolumeSizeInGB": 30, "InstanceCount": 1, "InstanceType": "ml.m5.large"}, "RoleArn": "arn:aws:iam::988060366449:role/service-role/AmazonSageMaker-ExecutionRole-20230817T134927", "InputDataConfig": [{"DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": "s3://udacity-ml-workflow/Lesson 3, Exercise 3/hello_blaze_train_scikit", "S3DataDistributionType": "FullyReplicated"}}, "ContentType": "text/plain", "ChannelName": "train"}, {"DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": "s3://udacity-ml-workflow/Lesson 3, Exercise 3/hello_blaze_train_scikit", "S3DataDistributionType": "FullyReplicated"}}, "ContentType": "text/plain", "ChannelName": "validation"}], "HyperParameters": {"mode": "supervised"}, "TrainingJobName": "hello-blaze-training-2023-09-08-213103", "DebugHookConfig": {"S3OutputPath": "s3://udacity-ml-workflow/Lesson 3, Exercise 3"}}, "Type": "Task", "End": true}}};
#     var elementId = '#graph-694';
#     var events = { 'events': [{"timestamp": 1694208665.482, "type": "ExecutionStarted", "id": 1, "previousEventId": 0, "executionStartedEventDetails": {"input": "{\n    \"PreprocessingJobName\": \"hello-blaze-preprocess-2023-09-08-213103\",\n    \"TrainingJobName\": \"hello-blaze-training-2023-09-08-213103\"\n}", "inputDetails": {"truncated": false}, "roleArn": "arn:aws:iam::988060366449:role/StepFunctionRole"}}, {"timestamp": 1694208665.516, "type": "TaskStateEntered", "id": 2, "previousEventId": 0, "stateEnteredEventDetails": {"name": "SageMaker pre-processing step 4", "input": "{\n    \"PreprocessingJobName\": \"hello-blaze-preprocess-2023-09-08-213103\",\n    \"TrainingJobName\": \"hello-blaze-training-2023-09-08-213103\"\n}", "inputDetails": {"truncated": false}}}, {"timestamp": 1694208665.516, "type": "TaskScheduled", "id": 3, "previousEventId": 2, "taskScheduledEventDetails": {"resourceType": "sagemaker", "resource": "createProcessingJob.sync", "region": "us-east-1", "parameters": "{\"ProcessingJobName\":\"hello-blaze-preprocess-2023-09-08-213103\",\"ProcessingInputs\":[{\"InputName\":\"input\",\"AppManaged\":false,\"S3Input\":{\"S3Uri\":\"s3://udacity-ml-workflow/Lesson 3, Exercise 3/reviews_Musical_Instruments_5.json.zip\",\"LocalPath\":\"/opt/ml/processing/input\",\"S3DataType\":\"S3Prefix\",\"S3InputMode\":\"File\",\"S3DataDistributionType\":\"FullyReplicated\",\"S3CompressionType\":\"None\"}},{\"InputName\":\"code\",\"AppManaged\":false,\"S3Input\":{\"S3Uri\":\"s3://udacity-ml-workflow/Lesson 3, Exercise 3/HelloBlazePreprocess.py\",\"LocalPath\":\"/opt/ml/processing/input/code\",\"S3DataType\":\"S3Prefix\",\"S3InputMode\":\"File\",\"S3DataDistributionType\":\"FullyReplicated\",\"S3CompressionType\":\"None\"}}],\"ProcessingOutputConfig\":{\"Outputs\":[{\"OutputName\":\"train_data\",\"AppManaged\":false,\"S3Output\":{\"S3Uri\":\"s3://udacity-ml-workflow/Lesson 3, Exercise 3/hello_blaze_train_scikit\",\"LocalPath\":\"/opt/ml/processing/output/train\",\"S3UploadMode\":\"EndOfJob\"}},{\"OutputName\":\"test_data\",\"AppManaged\":false,\"S3Output\":{\"S3Uri\":\"s3://udacity-ml-workflow/Lesson 3, Exercise 3/hello_blaze_train_scikit\",\"LocalPath\":\"/opt/ml/processing/output/test\",\"S3UploadMode\":\"EndOfJob\"}}]},\"AppSpecification\":{\"ImageUri\":\"683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-scikit-learn:0.20.0-cpu-py3\",\"ContainerEntrypoint\":[\"python3\",\"/opt/ml/processing/input/code/HelloBl

# %% [markdown]
# ## Re-execute Workflow

# %%
# Generate new unique names
VERSION = datetime.now().strftime("%Y-%m-%d-%H%M%S")
PREPROCESSING_JOB_NAME = "hello-blaze-preprocess-" + VERSION
TRAINING_JOB_NAME = "hello-blaze-training-" + VERSION

# Create new processing job
new_processing_step = ProcessingStep(
    "SageMaker pre-processing",
    processor=sklearn_processor,
    job_name=PREPROCESSING_JOB_NAME,
    inputs=inputs,
    outputs=outputs,
    container_entrypoint=["python3", "/opt/ml/processing/input/code/HelloBlazePreprocess.py"],
)

# Create new training step
new_training_step = TrainingStep(
    "SageMaker Training",
    estimator=helloBlazeEstimator,
    data={"train": sagemaker.TrainingInput(processed_data_train, content_type="text/plain"), 
          "validation": sagemaker.TrainingInput(processed_data_test, content_type="text/plain")},
    job_name=TRAINING_JOB_NAME,
    wait_for_completion=True,
)

# %%
# Update new definition
new_workflow_graph = Chain([new_processing_step, new_training_step])
workflow.update(definition=new_workflow_graph)
# Out:
# 'arn:aws:states:us-east-1:988060366449:stateMachine:hello-blaze-workflow'

# %%
# Execute
execution = workflow.execute(
    inputs={
        "PreprocessingJobName": PREPROCESSING_JOB_NAME,
        "TrainingJobName": TRAINING_JOB_NAME
    }
)
execution.get_output(wait=True)
execution.render_progress()
# Out:
# <link rel="stylesheet" type="text/css" href="https://do0of8uwbahzz.cloudfront.net/graph.css">
# <div id="graph-209" class="workflowgraph">
#
#     <style>
#         .graph-legend ul {
#             list-style-type: none;
#             padding: 10px;
#             padding-left: 0;
#             margin: 0;
#             position: absolute;
#             top: 0;
#             background: transparent;
#         }
#
#         .graph-legend li {
#             margin-left: 10px;
#             display: inline-block;
#         }
#
#         .graph-legend li > div {
#             width: 10px;
#             height: 10px;
#             display: inline-block;
#         }
#
#         .graph-legend .success { background-color: #2BD62E }
#         .graph-legend .failed { background-color: #DE322F }
#         .graph-legend .cancelled { background-color: #DDDDDD }
#         .graph-legend .in-progress { background-color: #53C9ED }
#         .graph-legend .caught-error { background-color: #FFA500 }
#     </style>
#     <div class="graph-legend">
#         <ul>
#             <li>
#                 <div class="success"></div>
#                 <span>Success</span>
#             </li>
#             <li>
#                 <div class="failed"></div>
#                 <span>Failed</span>
#             </li>
#             <li>
#                 <div class="cancelled"></div>
#                 <span>Cancelled</span>
#             </li>
#             <li>
#                 <div class="in-progress"></div>
#                 <span>In Progress</span>
#             </li>
#             <li>
#                 <div class="caught-error"></div>
#                 <span>Caught Error</span>
#             </li>
#         </ul>
#     </div>
#
#     <svg></svg>
#     <a href="https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:988060366449:execution:hello-blaze-workflow:69fb923b-d4f4-4c07-9f54-375f637f47e0" target="_blank"> Inspect in AWS Step Functions </a>
# </div>
#
# <script type="text/javascript">
#
# require.config({
#     paths: {
#         sfn: "https://do0of8uwbahzz.cloudfront.net/sfn",
#     }
# });
#
# require(['sfn'], function(sfn) {
#     var element = document.getElementById('graph-209')
#
#     var options = {
#         width: parseFloat(getComputedStyle(element, null).width.replace("px", "")),
#         height: 1000,
#         layout: 'LR',
#         resizeHeight: true
#     };
#
#     var definition = {"StartAt": "SageMaker pre-processing", "States": {"SageMaker pre-processing": {"Resource": "arn:aws:states:::sagemaker:createProcessingJob.sync", "Parameters": {"ProcessingJobName": "hello-blaze-preprocess-2023-09-08-214050", "ProcessingInputs": [{"InputName": "input", "AppManaged": false, "S3Input": {"S3Uri": "s3://udacity-ml-workflow/Lesson 3, Exercise 3/reviews_Musical_Instruments_5.json.zip", "LocalPath": "/opt/ml/processing/input", "S3DataType": "S3Prefix", "S3InputMode": "File", "S3DataDistributionType": "FullyReplicated", "S3CompressionType": "None"}}, {"InputName": "code", "AppManaged": false, "S3Input": {"S3Uri": "s3://udacity-ml-workflow/Lesson 3, Exercise 3/HelloBlazePreprocess.py", "LocalPath": "/opt/ml/processing/input/code", "S3DataType": "S3Prefix", "S3InputMode": "File", "S3DataDistributionType": "FullyReplicated", "S3CompressionType": "None"}}], "ProcessingOutputConfig": {"Outputs": [{"OutputName": "train_data", "AppManaged": false, "S3Output": {"S3Uri": "s3://udacity-ml-workflow/Lesson 3, Exercise 3/hello_blaze_train_scikit", "LocalPath": "/opt/ml/processing/output/train", "S3UploadMode": "EndOfJob"}}, {"OutputName": "test_data", "AppManaged": false, "S3Output": {"S3Uri": "s3://udacity-ml-workflow/Lesson 3, Exercise 3/hello_blaze_train_scikit", "LocalPath": "/opt/ml/processing/output/test", "S3UploadMode": "EndOfJob"}}]}, "AppSpecification": {"ImageUri": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-scikit-learn:0.20.0-cpu-py3", "ContainerEntrypoint": ["python3", "/opt/ml/processing/input/code/HelloBlazePreprocess.py"]}, "RoleArn": "arn:aws:iam::988060366449:role/service-role/AmazonSageMaker-ExecutionRole-20230817T134927", "ProcessingResources": {"ClusterConfig": {"InstanceCount": 1, "InstanceType": "ml.m5.large", "VolumeSizeInGB": 30}}}, "Type": "Task", "Next": "SageMaker Training"}, "SageMaker Training": {"Resource": "arn:aws:states:::sagemaker:createTrainingJob.sync", "Parameters": {"AlgorithmSpecification": {"TrainingImage": "811284229777.dkr.ecr.us-east-1.amazonaws.com/blazingtext:1", "TrainingInputMode": "File"}, "OutputDataConfig": {"S3OutputPath": "s3://udacity-ml-workflow/Lesson 3, Exercise 3"}, "StoppingCondition": {"MaxRuntimeInSeconds": 360000}, "ResourceConfig": {"VolumeSizeInGB": 30, "InstanceCount": 1, "InstanceType": "ml.m5.large"}, "RoleArn": "arn:aws:iam::988060366449:role/service-role/AmazonSageMaker-ExecutionRole-20230817T134927", "InputDataConfig": [{"DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": "s3://udacity-ml-workflow/Lesson 3, Exercise 3/hello_blaze_train_scikit", "S3DataDistributionType": "FullyReplicated"}}, "ContentType": "text/plain", "ChannelName": "train"}, {"DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": "s3://udacity-ml-workflow/Lesson 3, Exercise 3/hello_blaze_train_scikit", "S3DataDistributionType": "FullyReplicated"}}, "ContentType": "text/plain", "ChannelName": "validation"}], "HyperParameters": {"mode": "supervised"}, "TrainingJobName": "hello-blaze-training-2023-09-08-214050", "DebugHookConfig": {"S3OutputPath": "s3://udacity-ml-workflow/Lesson 3, Exercise 3"}}, "Type": "Task", "End": true}}};
#     var elementId = '#graph-209';
#     var events = { 'events': [{"timestamp": 1694209262.931, "type": "ExecutionStarted", "id": 1, "previousEventId": 0, "executionStartedEventDetails": {"input": "{\n    \"PreprocessingJobName\": \"hello-blaze-preprocess-2023-09-08-214050\",\n    \"TrainingJobName\": \"hello-blaze-training-2023-09-08-214050\"\n}", "inputDetails": {"truncated": false}, "roleArn": "arn:aws:iam::988060366449:role/StepFunctionRole"}}] };
#
#     var graph = new sfn.StateMachineExecutionGraph(definition, events, elementId, options);
#     graph.render();
# });
#
# </script>
